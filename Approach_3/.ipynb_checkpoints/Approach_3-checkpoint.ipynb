# %%
# source --> https://www.hackerearth.com/practice/machine-learning/transfer-learning/transfer-learning-intro/tutorial/

import numpy as np
import keras
from keras.datasets import cifar10
import matplotlib.pyplot as plt

#Load the dataset:
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
print("There are {} train images and {} test images.".format(X_train.shape[0], X_test.shape[0]))
print('There are {} unique classes to predict.'.format(np.unique(y_train).shape[0]))
# Out:
# There are 50000 train images and 10000 test images.
# There are 10 unique classes to predict.

# %%
#One-hot encoding the labels
num_classes = 10
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)

fig = plt.figure(figsize=(10, 10))

for i in range(1, 9):
    img = X_train[i-1]
    fig.add_subplot(2, 4, i)
    plt.imshow(img)

print("Shape of each image in the training data: ", X_train.shape[1:])
# Out:
# Shape of each image in the training data:  (32, 32, 3)

# %%
#Importing the necessary libraries 
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, GlobalAveragePooling2D

#Building up a Sequential model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu',input_shape = X_train.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(GlobalAveragePooling2D())
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          18496
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  global_average_pooling2d_1   (None, 64)               0
#  (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 29,290
# Trainable params: 29,290
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam',
              metrics=['accuracy'])
X_train_scratch = X_train/255.
X_test_scratch = X_test/255.

# %%
#Creating a checkpointer 
checkpointer = keras.callbacks.ModelCheckpoint(filepath='scratchmodel.best.hdf5', 
                               verbose=1,save_best_only=True)
#Fitting the model on the train data and labels.
model.fit(X_train, y_train, batch_size=32, epochs=10, 
          verbose=1, callbacks=[checkpointer], validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/10
# 2023-04-10 02:40:29.466214: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 122880000 exceeds 10% of free system memory.
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.2978 - accuracy: 0.3125
# Epoch 1: val_loss improved from inf to 0.25247, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.2978 - accuracy: 0.3127 - val_loss: 0.2525 - val_accuracy: 0.4117
# Epoch 2/10
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.2394 - accuracy: 0.4532
# Epoch 2: val_loss improved from 0.25247 to 0.22829, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.2394 - accuracy: 0.4533 - val_loss: 0.2283 - val_accuracy: 0.4748
# Epoch 3/10
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.2169 - accuracy: 0.5217
# Epoch 3: val_loss improved from 0.22829 to 0.21196, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.2169 - accuracy: 0.5219 - val_loss: 0.2120 - val_accuracy: 0.5419
# Epoch 4/10
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.2010 - accuracy: 0.5680
# Epoch 4: val_loss improved from 0.21196 to 0.20103, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.2009 - accuracy: 0.5679 - val_loss: 0.2010 - val_accuracy: 0.5678
# Epoch 5/10
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.1884 - accuracy: 0.6016
# Epoch 5: val_loss improved from 0.20103 to 0.19820, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1884 - accuracy: 0.6015 - val_loss: 0.1982 - val_accuracy: 0.5849
# Epoch 6/10
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.1807 - accuracy: 0.6244
# Epoch 6: val_loss improved from 0.19820 to 0.19302, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1807 - accuracy: 0.6245 - val_loss: 0.1930 - val_accuracy: 0.5956
# Epoch 7/10
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.1731 - accuracy: 0.6441
# Epoch 7: val_loss improved from 0.19302 to 0.18211, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1730 - accuracy: 0.6444 - val_loss: 0.1821 - val_accuracy: 0.6189
# Epoch 8/10
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.1663 - accuracy: 0.6632
# Epoch 8: val_loss improved from 0.18211 to 0.18177, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1663 - accuracy: 0.6633 - val_loss: 0.1818 - val_accuracy: 0.6323
# Epoch 9/10
# 1250/1250 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.6785
# Epoch 9: val_loss improved from 0.18177 to 0.18053, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1613 - accuracy: 0.6785 - val_loss: 0.1805 - val_accuracy: 0.6336
# Epoch 10/10
# 1248/1250 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.6885
# Epoch 10: val_loss improved from 0.18053 to 0.17765, saving model to scratchmodel.best.hdf5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.1564 - accuracy: 0.6885 - val_loss: 0.1777 - val_accuracy: 0.6415

# %%
#Evaluate the model on the test data
score = model.evaluate(X_test, y_test)

#Accuracy on test data
print('Accuracy on the Test Images: ', score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1817 - accuracy: 0.6344
# Accuracy on the Test Images:  0.6344000101089478

# %%
#Importing the ResNet50 model
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

#Loading the ResNet50 model with pre-trained ImageNet weights
model = ResNet50(weights='imagenet', include_top=False, input_shape=(200, 200, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 123s 1us/step

# %%
from skimage.transform import resize

#Reshaping the training data
#COULD BE PROBLEMATIC
X_train_new = np.array([resize(X_train[i], (200, 200, 3)) for i in range(0, len(X_train))]).astype('float32')

#Preprocessing the data, so that it can be fed to the pre-trained ResNet50 model. 
resnet_train_input = preprocess_input(X_train_new)

#Creating bottleneck features for the training data
train_features = model.predict(resnet_train_input)

#Saving the bottleneck features
np.savez('resnet_features_train', features=train_features)

# %%
#Reshaping the testing data
X_test_new = np.array([resize(X_test[i], (200, 200, 3)) for i in range(0, len(X_test))]).astype('float32')

#Preprocessing the data, so that it can be fed to the pre-trained ResNet50 model.
resnet_test_input = preprocess_input(X_test_new)

#Creating bottleneck features for the testing data
test_features = model.predict(resnet_test_input)

#Saving the bottleneck features
np.savez('resnet_features_test', features=test_features)

# %%
model = Sequential()
model.add(GlobalAveragePooling2D(input_shape=train_features.shape[1:]))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics=['accuracy'])

# %%
model.fit(train_features, y_train, batch_size=32, epochs=10,
          validation_split=0.2, callbacks=[checkpointer], verbose=1, shuffle=True)
